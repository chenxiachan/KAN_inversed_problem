# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from kan import KAN, add_symbolic
from torch.utils.data import TensorDataset, DataLoader

# Load the dataset
data_path = 'WallWindowTypicalDays_Winter Typical.csv'
data = pd.read_csv(data_path)

# Define input and output columns
input_columns = ['Temp', 'Dew', 'Hum', 'Pres', 'Wall Area', 'Window Area', 'Orientation', 'u-Value (Wall)', 'u-Value (Windows)', 'g-Value (Windows)']
output_column = 'Winter Typical:Heat Flow'
num_tasks = 3

# Prepare the data
X = data[input_columns].values
y = data[output_column].values

# Define subsampling rates
subsample_rates = [0.1, 0.05, 0.025, 0.001]

# Define the ANN model
class ANN(nn.Module):
    def __init__(self):
        super(ANN, self).__init__()
        self.layer1 = nn.Linear(X.shape[1], 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = self.layer3(x)
        return x

# Train the ANN model with early stopping
def train_ann(model, train_loader, val_loader, criterion, optimizer, epochs=200, patience=10):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        # Validation step
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                outputs = model(inputs)
                val_loss += criterion(outputs, targets).item()
        val_loss /= len(val_loader)

        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss:.4f}')

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered")
            break

    # Load the best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

# Evaluate the ANN model
def evaluate_ann(model, X_tensors, y_tensors):
    model.eval()
    all_predictions = []
    all_actuals = []
    with torch.no_grad():
        for X, y in zip(X_tensors, y_tensors):
            outputs = model(X)
            all_predictions.append(outputs.numpy())
            all_actuals.append(y.numpy())
    return all_predictions, all_actuals

# Define function to calculate performance metrics
def calculate_metrics(predictions, actuals, y_std, y_mean):
    predictions_denorm = predictions * y_std + y_mean
    actuals_denorm = actuals * y_std + y_mean
    mae = mean_absolute_error(actuals_denorm, predictions_denorm)
    mse = mean_squared_error(actuals_denorm, predictions_denorm)
    r2 = r2_score(actuals_denorm, predictions_denorm)
    return mae, mse, r2

# Train the KAN model using the tutorial's approach with early stopping
def train_kan_with_early_stopping(model, dataset, patience=5, steps=200):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    optimizer = torch.optim.LBFGS(model.parameters(), lr=1)

    def closure():
        optimizer.zero_grad()
        outputs = model(dataset['train_input'])
        loss = nn.MSELoss()(outputs, dataset['train_label'])
        loss.backward()
        return loss

    for step in range(steps):
        optimizer.step(closure)
        
        # Validation step
        with torch.no_grad():
            val_outputs = model(dataset['test_input'])
            val_loss = nn.MSELoss()(val_outputs, dataset['test_label']).item()

        print(f'Step [{step+1}/{steps}], Val Loss: {val_loss:.4f}')

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered")
            break

    # Load the best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

# Function to train and evaluate models on each subsample rate
def train_and_evaluate_models(subsample_rate, X, y):
    # Subsample the data
    if subsample_rate < 1:
        X_sub, _, y_sub, _ = train_test_split(X, y, test_size=1 - subsample_rate, random_state=42)
    else:
        X_sub, y_sub = X, y

    # Split the dataset into multiple tasks
    X_splits = np.array_split(X_sub, num_tasks)
    y_splits = np.array_split(y_sub, num_tasks)

    # Normalize the data
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()

    X_splits_scaled = [scaler_X.fit_transform(X_split) for X_split in X_splits]
    y_splits_scaled = [scaler_y.fit_transform(y_split.reshape(-1, 1)).flatten() for y_split in y_splits]

    # Convert to tensors
    X_splits_tensors = [torch.tensor(X_split, dtype=torch.float32) for X_split in X_splits_scaled]
    y_splits_tensors = [torch.tensor(y_split, dtype=torch.float32).unsqueeze(1) for y_split in y_splits_scaled]

    # Initialize and train the ANN model on sequential tasks
    ann_model = ANN()
    criterion = nn.MSELoss()
    optimizer = optim.Adam(ann_model.parameters(), lr=0.001)

    ann_r2_scores = [[] for _ in range(num_tasks)]
    for task_id in range(num_tasks):
        print(f"Training ANN on task {task_id + 1} with subsample rate {subsample_rate}")

        # Split the data into training and validation sets
        X_train, X_val, y_train, y_val = train_test_split(X_splits_tensors[task_id], y_splits_tensors[task_id], test_size=0.2, random_state=42)
        
        train_dataset = TensorDataset(X_train, y_train)
        train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

        val_dataset = TensorDataset(X_val, y_val)
        val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

        train_ann(ann_model, train_loader, val_loader, criterion, optimizer, epochs=200, patience=10)

        print("Evaluating ANN on all tasks")
        all_predictions, all_actuals = evaluate_ann(ann_model, X_splits_tensors, y_splits_tensors)
        for i in range(num_tasks):
            mae, mse, r2 = calculate_metrics(all_predictions[i], all_actuals[i], y_std=scaler_y.scale_[0], y_mean=scaler_y.mean_[0])
            ann_r2_scores[i].append(r2)
            print(f"Task {i + 1} - MAE: {mae}, MSE: {mse}, R2: {r2}")

    # Initialize and train the KAN model on sequential tasks
    kan_model = KAN(width=[len(input_columns), 5, 1], grid=10, k=10, seed=0)

    kan_r2_scores = [[] for _ in range(num_tasks)]
    for task_id in range(num_tasks):
        print(f"Training KAN on task {task_id + 1} with subsample rate {subsample_rate}")

        # Split the data into training and validation sets
        X_train, X_val, y_train, y_val = train_test_split(X_splits_tensors[task_id], y_splits_tensors[task_id], test_size=0.2, random_state=42)

        dataset = {
            'train_input': X_train,
            'train_label': y_train,
            'test_input': X_val,
            'test_label': y_val
        }
        train_kan_with_early_stopping(kan_model, dataset, patience=3, steps=100)

        print("Evaluating KAN on all tasks")
        all_predictions_kan = []
        for X in X_splits_tensors:
            with torch.no_grad():
                predictions_kan_scaled = kan_model(X).numpy()
            all_predictions_kan.append(predictions_kan_scaled)

        for i in range(num_tasks):
            mae, mse, r2 = calculate_metrics(all_predictions_kan[i], y_splits_scaled[i], y_std=scaler_y.scale_[0], y_mean=scaler_y.mean_[0])
            kan_r2_scores[i].append(r2)
            print(f"Task {i + 1} - MAE: {mae}, MSE: {mse}, R2: {r2}")

    return ann_r2_scores, kan_r2_scores

# Perform the training and evaluation for each subsample rate
all_ann_r2_scores = [[] for _ in range(num_tasks)]
all_kan_r2_scores = [[] for _ in range(num_tasks)]

for subsample_rate in subsample_rates:
    print(f"Subsample rate: {subsample_rate}")
    ann_r2_scores, kan_r2_scores = train_and_evaluate_models(subsample_rate, X, y)
    for i in range(num_tasks):
        all_ann_r2_scores[i].append(ann_r2_scores[i])
        all_kan_r2_scores[i].append(kan_r2_scores[i])

# Convert lists to numpy arrays for easier plotting
all_ann_r2_scores = np.array(all_ann_r2_scores)
all_kan_r2_scores = np.array(all_kan_r2_scores)

# Plot the R² comparison for ANN and KAN with different subsample rates for each task
for task_id in range(num_tasks):
    plt.figure(figsize=(14, 7))
    bar_width = 0.15
    index = np.arange(len(subsample_rates))

    plt.bar(index, all_ann_r2_scores[task_id][:, 0], bar_width, label=f'ANN Task 1')
    plt.bar(index + bar_width, all_ann_r2_scores[task_id][:, 1], bar_width, label=f'ANN Task 2')
    plt.bar(index + 2 * bar_width, all_ann_r2_scores[task_id][:, 2], bar_width, label=f'ANN Task 3')

    plt.bar(index + 3 * bar_width, all_kan_r2_scores[task_id][:, 0], bar_width, label=f'KAN Task 1', linestyle='--')
    plt.bar(index + 4 * bar_width, all_kan_r2_scores[task_id][:, 1], bar_width, label=f'KAN Task 2', linestyle='--')
    plt.bar(index + 5 * bar_width, all_kan_r2_scores[task_id][:, 2], bar_width, label=f'KAN Task 3', linestyle='--')

    plt.xlabel('Subsample Rate')
    plt.ylabel('R² Score')
    plt.title(f'R² Comparison of ANN and KAN with Different Subsample Rates for Task {task_id + 1}')
    plt.xticks(index + 2.5 * bar_width, subsample_rates)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'R2_Comparison_Subsample_Rates_Task_{task_id + 1}.png', dpi=300)
    plt.show()

# Plot the average R² comparison for ANN and KAN with different subsample rates
for task_id in range(num_tasks):
    plt.figure(figsize=(14, 7))
    bar_width = 0.35
    index = np.arange(len(subsample_rates))

    ann_mean_r2 = np.mean(all_ann_r2_scores[task_id], axis=1)
    kan_mean_r2 = np.mean(all_kan_r2_scores[task_id], axis=1)

    plt.bar(index - bar_width / 2, ann_mean_r2, bar_width, label='ANN')
    plt.bar(index + bar_width / 2, kan_mean_r2, bar_width, label='KAN')

    plt.xlabel('Subsample Rate')
    plt.ylabel('R² Score')
    plt.title(f'Average R² Comparison of ANN and KAN with Different Subsample Rates for Task {task_id + 1}')
    plt.xticks(index, subsample_rates)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'Average_R2_Comparison_Subsample_Rates_Task_{task_id + 1}.png', dpi=300)
    plt.show()
# Out:
# Subsample rate: 0.1
# Training ANN on task 1 with subsample rate 0.1
# Epoch [1/200], Loss: 0.4379, Val Loss: 0.8448
# Epoch [2/200], Loss: 0.1301, Val Loss: 0.8099
# Epoch [3/200], Loss: 0.3052, Val Loss: 0.7726
# Epoch [4/200], Loss: 9.6578, Val Loss: 0.7345
# Epoch [5/200], Loss: 0.4500, Val Loss: 0.7091
# Epoch [6/200], Loss: 0.1764, Val Loss: 0.6563
# Epoch [7/200], Loss: 0.2146, Val Loss: 0.6344
# Epoch [8/200], Loss: 6.6150, Val Loss: 0.6061
# Epoch [9/200], Loss: 1.0419, Val Loss: 0.5910
# Epoch [10/200], Loss: 0.2093, Val Loss: 0.5667
# Epoch [11/200], Loss: 2.5696, Val Loss: 0.5448
# Epoch [12/200], Loss: 0.4557, Val Loss: 0.5348
# Epoch [13/200], Loss: 0.1573, Val Loss: 0.5331
# Epoch [14/200], Loss: 0.1577, Val Loss: 0.5198
# Epoch [15/200], Loss: 0.1394, Val Loss: 0.5043
# Epoch [16/200], Loss: 0.3545, Val Loss: 0.5108
# Epoch [17/200], Loss: 2.1491, Val Loss: 0.4882
# Epoch [18/200], Loss: 0.0870, Val Loss: 0.4987
# Epoch [19/200], Loss: 0.2144, Val Loss: 0.4844
# Epoch [20/200], Loss: 0.2799, Val Loss: 0.4652
# Epoch [21/200], Loss: 0.1142, Val Loss: 0.4769
# Epoch [22/200], Loss: 0.1991, Val Loss: 0.4679
# Epoch [23/200], Loss: 0.1519, Val Loss: 0.4671
# Epoch [24/200], Loss: 0.1587, Val Loss: 0.4418
# Epoch [25/200], Loss: 0.1282, Val Loss: 0.4588
# Epoch [26/200], Loss: 0.0803, Val Loss: 0.4932
# Epoch [27/200], Loss: 1.2097, Val Loss: 0.4623
# Epoch [28/200], Loss: 0.0734, Val Loss: 0.4607
# Epoch [29/200], Loss: 0.0955, Val Loss: 0.4439
# Epoch [30/200], Loss: 0.1712, Val Loss: 0.4444
# Epoch [31/200], Loss: 0.1575, Val Loss: 0.4586
# Epoch [32/200], Loss: 0.1158, Val Loss: 0.4325
# Epoch [33/200], Loss: 0.0783, Val Loss: 0.4561
# Epoch [34/200], Loss: 0.2246, Val Loss: 0.4507
# Epoch [35/200], Loss: 0.1481, Val Loss: 0.4453
# Epoch [36/200], Loss: 0.2095, Val Loss: 0.4453
# Epoch [37/200], Loss: 0.0960, Val Loss: 0.4323
# Epoch [38/200], Loss: 0.2474, Val Loss: 0.4089
# Epoch [39/200], Loss: 0.1384, Val Loss: 0.4253
# Epoch [40/200], Loss: 0.1494, Val Loss: 0.4227
# Epoch [41/200], Loss: 0.0569, Val Loss: 0.4621
# Epoch [42/200], Loss: 0.2302, Val Loss: 0.3888
# Epoch [43/200], Loss: 0.0801, Val Loss: 0.4211
# Epoch [44/200], Loss: 0.1977, Val Loss: 0.4309
# Epoch [45/200], Loss: 0.0318, Val Loss: 0.4375
# Epoch [46/200], Loss: 0.0491, Val Loss: 0.4047
# Epoch [47/200], Loss: 0.2034, Val Loss: 0.4238
# Epoch [48/200], Loss: 3.8140, Val Loss: 0.4207
# Epoch [49/200], Loss: 0.1808, Val Loss: 0.3852
# Epoch [50/200], Loss: 0.1275, Val Loss: 0.3845
# Epoch [51/200], Loss: 0.1808, Val Loss: 0.4004
# Epoch [52/200], Loss: 0.1418, Val Loss: 0.3908
# Epoch [53/200], Loss: 0.0935, Val Loss: 0.3901
# Epoch [54/200], Loss: 0.0614, Val Loss: 0.3978
# Epoch [55/200], Loss: 0.1880, Val Loss: 0.4018
# Epoch [56/200], Loss: 0.3031, Val Loss: 0.4566
# Epoch [57/200], Loss: 0.0422, Val Loss: 0.4043
# Epoch [58/200], Loss: 0.4847, Val Loss: 0.3819
# Epoch [59/200], Loss: 0.2062, Val Loss: 0.4245
# Epoch [60/200], Loss: 0.1212, Val Loss: 0.3916
# Epoch [61/200], Loss: 1.4237, Val Loss: 0.3700
# Epoch [62/200], Loss: 0.2305, Val Loss: 0.4307
# Epoch [63/200], Loss: 0.1738, Val Loss: 0.3926
# Epoch [64/200], Loss: 0.2022, Val Loss: 0.3636
# Epoch [65/200], Loss: 0.2178, Val Loss: 0.3954
# Epoch [66/200], Loss: 0.1617, Val Loss: 0.4181
# Epoch [67/200], Loss: 0.1566, Val Loss: 0.3972
# Epoch [68/200], Loss: 0.1259, Val Loss: 0.3934
# Epoch [69/200], Loss: 0.0889, Val Loss: 0.3692
# Epoch [70/200], Loss: 0.1011, Val Loss: 0.3892
# Epoch [71/200], Loss: 0.1539, Val Loss: 0.3918
# Epoch [72/200], Loss: 0.0579, Val Loss: 0.4474
# Epoch [73/200], Loss: 0.1829, Val Loss: 0.4117
# Epoch [74/200], Loss: 0.1120, Val Loss: 0.4031
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 181.19009399414062, MSE: 82545.421875, R2: 0.7815157200229811
# Task 2 - MAE: 211.4252166748047, MSE: 137524.21875, R2: 0.6359958034947155
# Task 3 - MAE: 222.8798065185547, MSE: 137960.703125, R2: 0.6348405130700019
# Training ANN on task 2 with subsample rate 0.1
# Epoch [1/200], Loss: 0.0918, Val Loss: 0.3546
# Epoch [2/200], Loss: 0.0745, Val Loss: 0.3180
# Epoch [3/200], Loss: 0.3423, Val Loss: 0.3057
# Epoch [4/200], Loss: 0.0655, Val Loss: 0.3040
# Epoch [5/200], Loss: 0.1717, Val Loss: 0.3012
# Epoch [6/200], Loss: 0.1066, Val Loss: 0.3003
# Epoch [7/200], Loss: 0.1621, Val Loss: 0.2998
# Epoch [8/200], Loss: 0.0810, Val Loss: 0.3121
# Epoch [9/200], Loss: 0.3696, Val Loss: 0.2973
# Epoch [10/200], Loss: 0.0984, Val Loss: 0.2973
# Epoch [11/200], Loss: 0.0785, Val Loss: 0.2883
# Epoch [12/200], Loss: 0.0591, Val Loss: 0.2971
# Epoch [13/200], Loss: 0.0723, Val Loss: 0.3138
# Epoch [14/200], Loss: 0.1954, Val Loss: 0.2786
# Epoch [15/200], Loss: 0.0814, Val Loss: 0.2874
# Epoch [16/200], Loss: 0.1546, Val Loss: 0.2976
# Epoch [17/200], Loss: 0.0605, Val Loss: 0.2893
# Epoch [18/200], Loss: 0.2290, Val Loss: 0.2853
# Epoch [19/200], Loss: 0.1187, Val Loss: 0.2844
# Epoch [20/200], Loss: 0.1506, Val Loss: 0.3258
# Epoch [21/200], Loss: 0.0773, Val Loss: 0.2911
# Epoch [22/200], Loss: 0.0418, Val Loss: 0.2774
# Epoch [23/200], Loss: 0.0365, Val Loss: 0.2968
# Epoch [24/200], Loss: 0.0267, Val Loss: 0.2927
# Epoch [25/200], Loss: 0.1155, Val Loss: 0.2977
# Epoch [26/200], Loss: 0.3902, Val Loss: 0.2943
# Epoch [27/200], Loss: 0.0692, Val Loss: 0.2927
# Epoch [28/200], Loss: 0.0643, Val Loss: 0.2869
# Epoch [29/200], Loss: 0.1221, Val Loss: 0.3066
# Epoch [30/200], Loss: 0.0762, Val Loss: 0.2942
# Epoch [31/200], Loss: 0.0511, Val Loss: 0.2934
# Epoch [32/200], Loss: 0.4775, Val Loss: 0.2742
# Epoch [33/200], Loss: 0.0479, Val Loss: 0.2904
# Epoch [34/200], Loss: 0.1051, Val Loss: 0.2927
# Epoch [35/200], Loss: 0.1270, Val Loss: 0.2770
# Epoch [36/200], Loss: 0.1132, Val Loss: 0.2845
# Epoch [37/200], Loss: 0.1062, Val Loss: 0.2842
# Epoch [38/200], Loss: 0.0589, Val Loss: 0.2868
# Epoch [39/200], Loss: 0.0672, Val Loss: 0.3026
# Epoch [40/200], Loss: 0.0462, Val Loss: 0.2818
# Epoch [41/200], Loss: 0.0977, Val Loss: 0.2801
# Epoch [42/200], Loss: 0.2876, Val Loss: 0.2899
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 195.37396240234375, MSE: 100159.078125, R2: 0.7348952537041811
# Task 2 - MAE: 171.04788208007812, MSE: 73163.0859375, R2: 0.8063492305736468
# Task 3 - MAE: 208.8888702392578, MSE: 108524.703125, R2: 0.7127527955398374
# Training ANN on task 3 with subsample rate 0.1
# Epoch [1/200], Loss: 0.1053, Val Loss: 0.3076
# Epoch [2/200], Loss: 0.0888, Val Loss: 0.3081
# Epoch [3/200], Loss: 0.0606, Val Loss: 0.2786
# Epoch [4/200], Loss: 0.1964, Val Loss: 0.2851
# Epoch [5/200], Loss: 0.2048, Val Loss: 0.2940
# Epoch [6/200], Loss: 0.1056, Val Loss: 0.2886
# Epoch [7/200], Loss: 0.3099, Val Loss: 0.2760
# Epoch [8/200], Loss: 0.1033, Val Loss: 0.2989
# Epoch [9/200], Loss: 0.2665, Val Loss: 0.3082
# Epoch [10/200], Loss: 0.0750, Val Loss: 0.3167
# Epoch [11/200], Loss: 0.1032, Val Loss: 0.2764
# Epoch [12/200], Loss: 0.1201, Val Loss: 0.2905
# Epoch [13/200], Loss: 0.0321, Val Loss: 0.2598
# Epoch [14/200], Loss: 0.0772, Val Loss: 0.2781
# Epoch [15/200], Loss: 0.1701, Val Loss: 0.2698
# Epoch [16/200], Loss: 0.0954, Val Loss: 0.2941
# Epoch [17/200], Loss: 0.1116, Val Loss: 0.2975
# Epoch [18/200], Loss: 0.0813, Val Loss: 0.2449
# Epoch [19/200], Loss: 0.1588, Val Loss: 0.2616
# Epoch [20/200], Loss: 0.2379, Val Loss: 0.2410
# Epoch [21/200], Loss: 0.0884, Val Loss: 0.2607
# Epoch [22/200], Loss: 0.0961, Val Loss: 0.2578
# Epoch [23/200], Loss: 0.1802, Val Loss: 0.2745
# Epoch [24/200], Loss: 0.1176, Val Loss: 0.2730
# Epoch [25/200], Loss: 0.1428, Val Loss: 0.2525
# Epoch [26/200], Loss: 0.0834, Val Loss: 0.2525
# Epoch [27/200], Loss: 0.4093, Val Loss: 0.2529
# Epoch [28/200], Loss: 0.1096, Val Loss: 0.2452
# Epoch [29/200], Loss: 0.3677, Val Loss: 0.2407
# Epoch [30/200], Loss: 0.0616, Val Loss: 0.2653
# Epoch [31/200], Loss: 0.0714, Val Loss: 0.2640
# Epoch [32/200], Loss: 0.1287, Val Loss: 0.2344
# Epoch [33/200], Loss: 0.0852, Val Loss: 0.2329
# Epoch [34/200], Loss: 0.1431, Val Loss: 0.2341
# Epoch [35/200], Loss: 0.1378, Val Loss: 0.2703
# Epoch [36/200], Loss: 0.1470, Val Loss: 0.2514
# Epoch [37/200], Loss: 0.2658, Val Loss: 0.2482
# Epoch [38/200], Loss: 0.0944, Val Loss: 0.2358
# Epoch [39/200], Loss: 0.2506, Val Loss: 0.2348
# Epoch [40/200], Loss: 0.0532, Val Loss: 0.2439
# Epoch [41/200], Loss: 0.1237, Val Loss: 0.2425
# Epoch [42/200], Loss: 0.1445, Val Loss: 0.2327
# Epoch [43/200], Loss: 0.1351, Val Loss: 0.2375
# Epoch [44/200], Loss: 0.0595, Val Loss: 0.2399
# Epoch [45/200], Loss: 0.0610, Val Loss: 0.2414
# Epoch [46/200], Loss: 0.1171, Val Loss: 0.2389
# Epoch [47/200], Loss: 0.0714, Val Loss: 0.2322
# Epoch [48/200], Loss: 0.0868, Val Loss: 0.2437
# Epoch [49/200], Loss: 0.1129, Val Loss: 0.2355
# Epoch [50/200], Loss: 0.0387, Val Loss: 0.2389
# Epoch [51/200], Loss: 0.1035, Val Loss: 0.2275
# Epoch [52/200], Loss: 0.1745, Val Loss: 0.2330
# Epoch [53/200], Loss: 0.0715, Val Loss: 0.2465
# Epoch [54/200], Loss: 0.1145, Val Loss: 0.2397
# Epoch [55/200], Loss: 0.1150, Val Loss: 0.2501
# Epoch [56/200], Loss: 0.1675, Val Loss: 0.2364
# Epoch [57/200], Loss: 0.0675, Val Loss: 0.2158
# Epoch [58/200], Loss: 0.0436, Val Loss: 0.2216
# Epoch [59/200], Loss: 0.0850, Val Loss: 0.2251
# Epoch [60/200], Loss: 0.0722, Val Loss: 0.2165
# Epoch [61/200], Loss: 0.1071, Val Loss: 0.2423
# Epoch [62/200], Loss: 0.1025, Val Loss: 0.2280
# Epoch [63/200], Loss: 0.0968, Val Loss: 0.2254
# Epoch [64/200], Loss: 0.2589, Val Loss: 0.2235
# Epoch [65/200], Loss: 0.0442, Val Loss: 0.2226
# Epoch [66/200], Loss: 0.3214, Val Loss: 0.2167
# Epoch [67/200], Loss: 0.1494, Val Loss: 0.2601
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 188.18971252441406, MSE: 94189.0390625, R2: 0.7506969423469732
# Task 2 - MAE: 183.9415740966797, MSE: 93442.109375, R2: 0.7526739562782343
# Task 3 - MAE: 161.85321044921875, MSE: 57505.546875, R2: 0.8477921857365852
# Training KAN on task 1 with subsample rate 0.1
# Step [1/100], Val Loss: 0.6438
# Step [2/100], Val Loss: 0.4665
# Step [3/100], Val Loss: 0.4258
# Step [4/100], Val Loss: 0.4087
# Step [5/100], Val Loss: 0.4296
# Step [6/100], Val Loss: 0.4295
# Step [7/100], Val Loss: 0.4583
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 164.94210973653696, MSE: 74138.8483211817, R2: 0.8037665539520986
# Task 2 - MAE: 214.77625913128318, MSE: 187356.34794059538, R2: 0.5040982881733191
# Task 3 - MAE: 216.5115367532361, MSE: 157766.364479744, R2: 0.5824181508972229
# Training KAN on task 2 with subsample rate 0.1
# Step [1/100], Val Loss: 0.2995
# Step [2/100], Val Loss: 0.3113
# Step [3/100], Val Loss: 0.3454
# Step [4/100], Val Loss: 0.3800
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 225.9703886567066, MSE: 157155.73533443228, R2: 0.5840343867055092
# Task 2 - MAE: 166.57787142781527, MSE: 78696.75753025549, R2: 0.7917025112656617
# Task 3 - MAE: 212.28081228686864, MSE: 144240.12744190823, R2: 0.6182198954090394
# Training KAN on task 3 with subsample rate 0.1
# Step [1/100], Val Loss: 0.4317
# Step [2/100], Val Loss: 0.4140
# Step [3/100], Val Loss: 0.4626
# Step [4/100], Val Loss: 0.4587
# Step [5/100], Val Loss: 0.4332
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 214.91616830962553, MSE: 149663.10535059392, R2: 0.6038661568905657
# Task 2 - MAE: 189.1381775314434, MSE: 133106.65597268756, R2: 0.6476883795081776
# Task 3 - MAE: 154.59304148387315, MSE: 69583.17985260562, R2: 0.8158246657637039
# Subsample rate: 0.05
# Training ANN on task 1 with subsample rate 0.05
# Epoch [1/200], Loss: 0.2302, Val Loss: 0.7601
# Epoch [2/200], Loss: 0.1502, Val Loss: 0.7359
# Epoch [3/200], Loss: 0.7261, Val Loss: 0.7196
# Epoch [4/200], Loss: 0.0228, Val Loss: 0.7017
# Epoch [5/200], Loss: 0.2423, Val Loss: 0.6877
# Epoch [6/200], Loss: 0.0679, Val Loss: 0.6865
# Epoch [7/200], Loss: 0.0336, Val Loss: 0.6721
# Epoch [8/200], Loss: 0.3076, Val Loss: 0.6810
# Epoch [9/200], Loss: 0.2398, Val Loss: 0.6648
# Epoch [10/200], Loss: 0.4361, Val Loss: 0.6364
# Epoch [11/200], Loss: 0.3262, Val Loss: 0.6490
# Epoch [12/200], Loss: 0.0468, Val Loss: 0.6377
# Epoch [13/200], Loss: 0.1226, Val Loss: 0.6363
# Epoch [14/200], Loss: 0.3302, Val Loss: 0.6190
# Epoch [15/200], Loss: 0.5011, Val Loss: 0.6318
# Epoch [16/200], Loss: 0.0478, Val Loss: 0.6126
# Epoch [17/200], Loss: 0.3107, Val Loss: 0.6191
# Epoch [18/200], Loss: 0.2340, Val Loss: 0.6039
# Epoch [19/200], Loss: 0.1566, Val Loss: 0.6180
# Epoch [20/200], Loss: 0.2463, Val Loss: 0.5778
# Epoch [21/200], Loss: 0.1489, Val Loss: 0.5957
# Epoch [22/200], Loss: 0.2293, Val Loss: 0.5673
# Epoch [23/200], Loss: 0.0296, Val Loss: 0.5840
# Epoch [24/200], Loss: 0.1100, Val Loss: 0.5939
# Epoch [25/200], Loss: 0.1347, Val Loss: 0.5790
# Epoch [26/200], Loss: 0.5028, Val Loss: 0.5891
# Epoch [27/200], Loss: 0.3609, Val Loss: 0.5929
# Epoch [28/200], Loss: 0.3995, Val Loss: 0.5589
# Epoch [29/200], Loss: 0.2531, Val Loss: 0.5832
# Epoch [30/200], Loss: 0.6692, Val Loss: 0.5564
# Epoch [31/200], Loss: 0.2554, Val Loss: 0.5799
# Epoch [32/200], Loss: 0.2496, Val Loss: 0.5701
# Epoch [33/200], Loss: 0.0536, Val Loss: 0.5709
# Epoch [34/200], Loss: 0.0887, Val Loss: 0.5569
# Epoch [35/200], Loss: 0.0468, Val Loss: 0.5518
# Epoch [36/200], Loss: 0.0640, Val Loss: 0.5500
# Epoch [37/200], Loss: 0.2311, Val Loss: 0.5515
# Epoch [38/200], Loss: 0.2490, Val Loss: 0.5705
# Epoch [39/200], Loss: 0.0290, Val Loss: 0.5381
# Epoch [40/200], Loss: 0.0679, Val Loss: 0.5604
# Epoch [41/200], Loss: 0.0329, Val Loss: 0.5491
# Epoch [42/200], Loss: 0.6372, Val Loss: 0.5469
# Epoch [43/200], Loss: 0.2072, Val Loss: 0.5563
# Epoch [44/200], Loss: 0.0922, Val Loss: 0.5555
# Epoch [45/200], Loss: 0.7353, Val Loss: 0.5342
# Epoch [46/200], Loss: 0.1729, Val Loss: 0.5667
# Epoch [47/200], Loss: 0.0284, Val Loss: 0.5372
# Epoch [48/200], Loss: 0.3805, Val Loss: 0.5891
# Epoch [49/200], Loss: 0.0403, Val Loss: 0.5646
# Epoch [50/200], Loss: 0.1003, Val Loss: 0.5404
# Epoch [51/200], Loss: 2.2297, Val Loss: 0.5342
# Epoch [52/200], Loss: 1.5739, Val Loss: 0.5596
# Epoch [53/200], Loss: 0.1882, Val Loss: 0.5427
# Epoch [54/200], Loss: 0.0551, Val Loss: 0.6078
# Epoch [55/200], Loss: 0.8733, Val Loss: 0.5396
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 211.02325439453125, MSE: 122882.046875, R2: 0.6822337044671722
# Task 2 - MAE: 281.68426513671875, MSE: 234150.234375, R2: 0.39450025122369814
# Task 3 - MAE: 269.5721435546875, MSE: 209444.15625, R2: 0.4583888303932585
# Training ANN on task 2 with subsample rate 0.05
# Epoch [1/200], Loss: 0.7987, Val Loss: 0.5896
# Epoch [2/200], Loss: 0.2679, Val Loss: 0.5330
# Epoch [3/200], Loss: 0.1138, Val Loss: 0.5306
# Epoch [4/200], Loss: 0.8615, Val Loss: 0.5121
# Epoch [5/200], Loss: 0.1757, Val Loss: 0.4822
# Epoch [6/200], Loss: 0.3554, Val Loss: 0.5021
# Epoch [7/200], Loss: 0.1390, Val Loss: 0.4741
# Epoch [8/200], Loss: 0.4635, Val Loss: 0.4665
# Epoch [9/200], Loss: 0.2178, Val Loss: 0.4821
# Epoch [10/200], Loss: 0.0542, Val Loss: 0.4953
# Epoch [11/200], Loss: 0.2059, Val Loss: 0.4872
# Epoch [12/200], Loss: 0.1756, Val Loss: 0.4770
# Epoch [13/200], Loss: 1.2982, Val Loss: 0.4442
# Epoch [14/200], Loss: 0.1563, Val Loss: 0.4774
# Epoch [15/200], Loss: 0.6668, Val Loss: 0.4673
# Epoch [16/200], Loss: 0.2920, Val Loss: 0.4501
# Epoch [17/200], Loss: 0.1150, Val Loss: 0.4859
# Epoch [18/200], Loss: 0.0980, Val Loss: 0.4504
# Epoch [19/200], Loss: 1.8225, Val Loss: 0.4309
# Epoch [20/200], Loss: 0.3444, Val Loss: 0.4485
# Epoch [21/200], Loss: 0.2233, Val Loss: 0.4599
# Epoch [22/200], Loss: 0.1109, Val Loss: 0.4584
# Epoch [23/200], Loss: 0.0198, Val Loss: 0.4345
# Epoch [24/200], Loss: 0.0996, Val Loss: 0.4470
# Epoch [25/200], Loss: 0.1879, Val Loss: 0.4323
# Epoch [26/200], Loss: 0.0910, Val Loss: 0.4390
# Epoch [27/200], Loss: 0.1623, Val Loss: 0.4252
# Epoch [28/200], Loss: 0.1261, Val Loss: 0.4332
# Epoch [29/200], Loss: 0.0529, Val Loss: 0.4302
# Epoch [30/200], Loss: 0.1023, Val Loss: 0.4240
# Epoch [31/200], Loss: 0.0532, Val Loss: 0.4027
# Epoch [32/200], Loss: 0.2688, Val Loss: 0.4206
# Epoch [33/200], Loss: 0.0547, Val Loss: 0.4198
# Epoch [34/200], Loss: 0.1671, Val Loss: 0.4115
# Epoch [35/200], Loss: 0.5666, Val Loss: 0.3999
# Epoch [36/200], Loss: 0.2584, Val Loss: 0.4038
# Epoch [37/200], Loss: 0.0688, Val Loss: 0.4003
# Epoch [38/200], Loss: 0.1357, Val Loss: 0.4136
# Epoch [39/200], Loss: 0.0981, Val Loss: 0.4107
# Epoch [40/200], Loss: 0.0678, Val Loss: 0.3921
# Epoch [41/200], Loss: 0.1371, Val Loss: 0.4022
# Epoch [42/200], Loss: 0.1244, Val Loss: 0.4122
# Epoch [43/200], Loss: 0.1371, Val Loss: 0.4212
# Epoch [44/200], Loss: 0.1222, Val Loss: 0.3868
# Epoch [45/200], Loss: 0.5228, Val Loss: 0.4013
# Epoch [46/200], Loss: 0.2121, Val Loss: 0.4078
# Epoch [47/200], Loss: 0.0883, Val Loss: 0.3808
# Epoch [48/200], Loss: 0.1268, Val Loss: 0.4081
# Epoch [49/200], Loss: 0.1929, Val Loss: 0.3898
# Epoch [50/200], Loss: 0.1070, Val Loss: 0.3857
# Epoch [51/200], Loss: 0.4353, Val Loss: 0.3807
# Epoch [52/200], Loss: 0.2042, Val Loss: 0.4033
# Epoch [53/200], Loss: 0.1399, Val Loss: 0.3874
# Epoch [54/200], Loss: 0.1618, Val Loss: 0.3936
# Epoch [55/200], Loss: 0.0686, Val Loss: 0.3861
# Epoch [56/200], Loss: 0.1273, Val Loss: 0.3996
# Epoch [57/200], Loss: 0.0739, Val Loss: 0.3765
# Epoch [58/200], Loss: 0.1636, Val Loss: 0.3957
# Epoch [59/200], Loss: 0.1534, Val Loss: 0.3916
# Epoch [60/200], Loss: 0.2124, Val Loss: 0.3808
# Epoch [61/200], Loss: 0.0395, Val Loss: 0.3880
# Epoch [62/200], Loss: 0.0708, Val Loss: 0.3803
# Epoch [63/200], Loss: 0.9499, Val Loss: 0.3766
# Epoch [64/200], Loss: 0.0225, Val Loss: 0.3974
# Epoch [65/200], Loss: 0.1429, Val Loss: 0.3736
# Epoch [66/200], Loss: 0.1577, Val Loss: 0.3951
# Epoch [67/200], Loss: 0.3628, Val Loss: 0.3801
# Epoch [68/200], Loss: 0.0955, Val Loss: 0.3857
# Epoch [69/200], Loss: 0.1416, Val Loss: 0.4008
# Epoch [70/200], Loss: 0.1426, Val Loss: 0.4010
# Epoch [71/200], Loss: 0.1218, Val Loss: 0.3825
# Epoch [72/200], Loss: 0.0402, Val Loss: 0.3727
# Epoch [73/200], Loss: 0.1398, Val Loss: 0.3959
# Epoch [74/200], Loss: 0.2451, Val Loss: 0.3793
# Epoch [75/200], Loss: 0.2545, Val Loss: 0.3794
# Epoch [76/200], Loss: 0.0280, Val Loss: 0.3936
# Epoch [77/200], Loss: 0.1650, Val Loss: 0.3913
# Epoch [78/200], Loss: 0.1824, Val Loss: 0.3824
# Epoch [79/200], Loss: 0.1631, Val Loss: 0.3739
# Epoch [80/200], Loss: 0.1663, Val Loss: 0.3792
# Epoch [81/200], Loss: 0.2271, Val Loss: 0.3823
# Epoch [82/200], Loss: 0.0846, Val Loss: 0.3730
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 238.16644287109375, MSE: 155408.625, R2: 0.5981217263657028
# Task 2 - MAE: 195.8699951171875, MSE: 79550.9921875, R2: 0.7942854511139252
# Task 3 - MAE: 255.88754272460938, MSE: 171008.625, R2: 0.5577810088225622
# Training ANN on task 3 with subsample rate 0.05
# Epoch [1/200], Loss: 0.1657, Val Loss: 0.4701
# Epoch [2/200], Loss: 0.1661, Val Loss: 0.4720
# Epoch [3/200], Loss: 0.3102, Val Loss: 0.4315
# Epoch [4/200], Loss: 0.1915, Val Loss: 0.3961
# Epoch [5/200], Loss: 0.6133, Val Loss: 0.4263
# Epoch [6/200], Loss: 0.1270, Val Loss: 0.4104
# Epoch [7/200], Loss: 1.0090, Val Loss: 0.4080
# Epoch [8/200], Loss: 0.2596, Val Loss: 0.4461
# Epoch [9/200], Loss: 0.1046, Val Loss: 0.4141
# Epoch [10/200], Loss: 0.0645, Val Loss: 0.4184
# Epoch [11/200], Loss: 0.0577, Val Loss: 0.4129
# Epoch [12/200], Loss: 0.3453, Val Loss: 0.4009
# Epoch [13/200], Loss: 0.2235, Val Loss: 0.4243
# Epoch [14/200], Loss: 0.3596, Val Loss: 0.4464
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 233.57630920410156, MSE: 145471.265625, R2: 0.6238192050444422
# Task 2 - MAE: 237.3197479248047, MSE: 116757.6875, R2: 0.6980709627466715
# Task 3 - MAE: 217.7638397216797, MSE: 105098.2109375, R2: 0.7282217484731902
# Training KAN on task 1 with subsample rate 0.05
# Step [1/100], Val Loss: 0.6559
# Step [2/100], Val Loss: 0.5327
# Step [3/100], Val Loss: 0.4039
# Step [4/100], Val Loss: 0.4008
# Step [5/100], Val Loss: 0.3800
# Step [6/100], Val Loss: 0.3939
# Step [7/100], Val Loss: 0.3925
# Step [8/100], Val Loss: 0.3995
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 146.80875001875128, MSE: 54876.95344435401, R2: 0.8580911839201414
# Task 2 - MAE: 257.3448389067854, MSE: 223552.24323283182, R2: 0.4219060611421087
# Task 3 - MAE: 249.81387136634618, MSE: 215567.67954304456, R2: 0.44255370845148234
# Training KAN on task 2 with subsample rate 0.05
# Step [1/100], Val Loss: 0.4260
# Step [2/100], Val Loss: 0.4412
# Step [3/100], Val Loss: 0.4518
# Step [4/100], Val Loss: 0.4824
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 225.6651179796584, MSE: 145847.57810498244, R2: 0.62284609771605
# Task 2 - MAE: 174.65109013187325, MSE: 74043.13868727878, R2: 0.8085284715995918
# Task 3 - MAE: 242.1770400555585, MSE: 205452.2188157207, R2: 0.46871173957054624
# Training KAN on task 3 with subsample rate 0.05
# Step [1/100], Val Loss: 0.3701
# Step [2/100], Val Loss: 0.3748
# Step [3/100], Val Loss: 0.5069
# Step [4/100], Val Loss: 0.6475
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 235.71454356469982, MSE: 209354.75056398212, R2: 0.4586200047829836
# Task 2 - MAE: 239.78870251712672, MSE: 221206.04333361014, R2: 0.427973206438774
# Task 3 - MAE: 167.6430948402262, MSE: 86493.00930682164, R2: 0.7763337835005477
# Subsample rate: 0.025
# Training ANN on task 1 with subsample rate 0.025
# Epoch [1/200], Loss: 0.0805, Val Loss: 0.6200
# Epoch [2/200], Loss: 1.0041, Val Loss: 0.5962
# Epoch [3/200], Loss: 0.9697, Val Loss: 0.5879
# Epoch [4/200], Loss: 0.0790, Val Loss: 0.5819
# Epoch [5/200], Loss: 0.3468, Val Loss: 0.5791
# Epoch [6/200], Loss: 0.0421, Val Loss: 0.5806
# Epoch [7/200], Loss: 0.3622, Val Loss: 0.5686
# Epoch [8/200], Loss: 0.1120, Val Loss: 0.5776
# Epoch [9/200], Loss: 0.5452, Val Loss: 0.5656
# Epoch [10/200], Loss: 22.5233, Val Loss: 0.5658
# Epoch [11/200], Loss: 0.1908, Val Loss: 0.5624
# Epoch [12/200], Loss: 0.0642, Val Loss: 0.5537
# Epoch [13/200], Loss: 0.7981, Val Loss: 0.5542
# Epoch [14/200], Loss: 0.3103, Val Loss: 0.5502
# Epoch [15/200], Loss: 1.0866, Val Loss: 0.5429
# Epoch [16/200], Loss: 0.2136, Val Loss: 0.5403
# Epoch [17/200], Loss: 0.0745, Val Loss: 0.5490
# Epoch [18/200], Loss: 0.1342, Val Loss: 0.5434
# Epoch [19/200], Loss: 0.2895, Val Loss: 0.5461
# Epoch [20/200], Loss: 0.1902, Val Loss: 0.5376
# Epoch [21/200], Loss: 0.8065, Val Loss: 0.5344
# Epoch [22/200], Loss: 0.4341, Val Loss: 0.5366
# Epoch [23/200], Loss: 0.1306, Val Loss: 0.5369
# Epoch [24/200], Loss: 0.1687, Val Loss: 0.5407
# Epoch [25/200], Loss: 0.3327, Val Loss: 0.5431
# Epoch [26/200], Loss: 0.1620, Val Loss: 0.5485
# Epoch [27/200], Loss: 0.0927, Val Loss: 0.5620
# Epoch [28/200], Loss: 0.3608, Val Loss: 0.5458
# Epoch [29/200], Loss: 0.0349, Val Loss: 0.5588
# Epoch [30/200], Loss: 0.1609, Val Loss: 0.5612
# Epoch [31/200], Loss: 0.1311, Val Loss: 0.5495
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 260.9100646972656, MSE: 201327.234375, R2: 0.44389955719972374
# Task 2 - MAE: 283.1611633300781, MSE: 255817.078125, R2: 0.2933892036079443
# Task 3 - MAE: 283.3033752441406, MSE: 240763.9375, R2: 0.3349685871502637
# Training ANN on task 2 with subsample rate 0.025
# Epoch [1/200], Loss: 0.0788, Val Loss: 0.4327
# Epoch [2/200], Loss: 0.0764, Val Loss: 0.4276
# Epoch [3/200], Loss: 0.0818, Val Loss: 0.4373
# Epoch [4/200], Loss: 0.0076, Val Loss: 0.4307
# Epoch [5/200], Loss: 1.4718, Val Loss: 0.4404
# Epoch [6/200], Loss: 0.0390, Val Loss: 0.4425
# Epoch [7/200], Loss: 0.7473, Val Loss: 0.4479
# Epoch [8/200], Loss: 0.1483, Val Loss: 0.4378
# Epoch [9/200], Loss: 0.2504, Val Loss: 0.4372
# Epoch [10/200], Loss: 0.2354, Val Loss: 0.4310
# Epoch [11/200], Loss: 0.0124, Val Loss: 0.4349
# Epoch [12/200], Loss: 0.5924, Val Loss: 0.4327
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 293.65838623046875, MSE: 233700.15625, R2: 0.35447999438834876
# Task 2 - MAE: 248.34812927246094, MSE: 164450.296875, R2: 0.5457599939636093
# Task 3 - MAE: 290.0951843261719, MSE: 242066.5, R2: 0.33137067266200615
# Training ANN on task 3 with subsample rate 0.025
# Epoch [1/200], Loss: 0.1833, Val Loss: 0.5349
# Epoch [2/200], Loss: 0.1454, Val Loss: 0.5228
# Epoch [3/200], Loss: 0.0958, Val Loss: 0.5211
# Epoch [4/200], Loss: 0.4783, Val Loss: 0.5272
# Epoch [5/200], Loss: 0.2420, Val Loss: 0.5192
# Epoch [6/200], Loss: 0.0911, Val Loss: 0.5136
# Epoch [7/200], Loss: 0.0677, Val Loss: 0.5093
# Epoch [8/200], Loss: 0.0810, Val Loss: 0.5209
# Epoch [9/200], Loss: 0.3816, Val Loss: 0.5216
# Epoch [10/200], Loss: 0.2489, Val Loss: 0.5063
# Epoch [11/200], Loss: 0.1053, Val Loss: 0.5067
# Epoch [12/200], Loss: 0.2729, Val Loss: 0.5208
# Epoch [13/200], Loss: 0.1110, Val Loss: 0.5120
# Epoch [14/200], Loss: 0.0586, Val Loss: 0.5227
# Epoch [15/200], Loss: 0.1905, Val Loss: 0.5185
# Epoch [16/200], Loss: 0.1192, Val Loss: 0.5152
# Epoch [17/200], Loss: 0.1269, Val Loss: 0.5174
# Epoch [18/200], Loss: 0.1191, Val Loss: 0.5071
# Epoch [19/200], Loss: 0.1778, Val Loss: 0.5060
# Epoch [20/200], Loss: 0.2595, Val Loss: 0.5148
# Epoch [21/200], Loss: 0.1076, Val Loss: 0.5101
# Epoch [22/200], Loss: 0.2287, Val Loss: 0.5061
# Epoch [23/200], Loss: 0.1623, Val Loss: 0.5368
# Epoch [24/200], Loss: 0.7857, Val Loss: 0.5143
# Epoch [25/200], Loss: 1.7667, Val Loss: 0.5134
# Epoch [26/200], Loss: 0.1307, Val Loss: 0.5145
# Epoch [27/200], Loss: 0.0531, Val Loss: 0.5087
# Epoch [28/200], Loss: 0.2594, Val Loss: 0.4951
# Epoch [29/200], Loss: 0.2258, Val Loss: 0.5035
# Epoch [30/200], Loss: 0.0446, Val Loss: 0.5210
# Epoch [31/200], Loss: 0.0139, Val Loss: 0.5035
# Epoch [32/200], Loss: 0.0518, Val Loss: 0.5063
# Epoch [33/200], Loss: 0.2259, Val Loss: 0.4995
# Epoch [34/200], Loss: 0.0121, Val Loss: 0.4909
# Epoch [35/200], Loss: 0.0452, Val Loss: 0.5137
# Epoch [36/200], Loss: 0.1069, Val Loss: 0.4952
# Epoch [37/200], Loss: 0.0486, Val Loss: 0.5052
# Epoch [38/200], Loss: 0.0338, Val Loss: 0.4857
# Epoch [39/200], Loss: 0.0340, Val Loss: 0.4998
# Epoch [40/200], Loss: 0.0552, Val Loss: 0.4984
# Epoch [41/200], Loss: 0.0161, Val Loss: 0.4899
# Epoch [42/200], Loss: 0.0692, Val Loss: 0.4717
# Epoch [43/200], Loss: 0.0590, Val Loss: 0.4817
# Epoch [44/200], Loss: 0.2854, Val Loss: 0.4951
# Epoch [45/200], Loss: 0.1429, Val Loss: 0.4957
# Epoch [46/200], Loss: 0.1317, Val Loss: 0.4813
# Epoch [47/200], Loss: 0.1045, Val Loss: 0.4803
# Epoch [48/200], Loss: 0.0383, Val Loss: 0.4850
# Epoch [49/200], Loss: 1.7218, Val Loss: 0.4913
# Epoch [50/200], Loss: 0.0294, Val Loss: 0.5009
# Epoch [51/200], Loss: 0.0479, Val Loss: 0.5052
# Epoch [52/200], Loss: 0.1095, Val Loss: 0.4680
# Epoch [53/200], Loss: 0.0311, Val Loss: 0.4921
# Epoch [54/200], Loss: 0.1107, Val Loss: 0.4910
# Epoch [55/200], Loss: 0.1417, Val Loss: 0.4726
# Epoch [56/200], Loss: 0.0717, Val Loss: 0.4860
# Epoch [57/200], Loss: 0.0256, Val Loss: 0.5087
# Epoch [58/200], Loss: 5.2083, Val Loss: 0.4917
# Epoch [59/200], Loss: 0.3410, Val Loss: 0.5276
# Epoch [60/200], Loss: 0.0517, Val Loss: 0.4943
# Epoch [61/200], Loss: 0.1233, Val Loss: 0.5490
# Epoch [62/200], Loss: 0.1383, Val Loss: 0.4702
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 280.67254638671875, MSE: 212105.84375, R2: 0.41412718599249354
# Task 2 - MAE: 266.76177978515625, MSE: 207793.484375, R2: 0.42603869495699354
# Task 3 - MAE: 202.7960968017578, MSE: 98162.40625, R2: 0.7288585542915245
# Training KAN on task 1 with subsample rate 0.025
# Step [1/100], Val Loss: 0.6561
# Step [2/100], Val Loss: 0.8261
# Step [3/100], Val Loss: 1.0315
# Step [4/100], Val Loss: 1.0782
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 241.70453664309966, MSE: 138510.27777344268, R2: 0.617410800358899
# Task 2 - MAE: 412.29870370874613, MSE: 426807.4824208069, R2: -0.17891564239948865
# Task 3 - MAE: 405.40689996712223, MSE: 367071.6446421656, R2: -0.01391498878010089
# Training KAN on task 2 with subsample rate 0.025
# Step [1/100], Val Loss: 0.6505
# Step [2/100], Val Loss: 0.8705
# Step [3/100], Val Loss: 0.8847
# Step [4/100], Val Loss: 0.9894
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 427.9688623393744, MSE: 414761.6757138153, R2: -0.1456430533819617
# Task 2 - MAE: 215.2711853856534, MSE: 119984.75934539318, R2: 0.6685814671300466
# Task 3 - MAE: 411.3547643917346, MSE: 380895.7217793964, R2: -0.0520994664429133
# Training KAN on task 3 with subsample rate 0.025
# Step [1/100], Val Loss: 0.5717
# Step [2/100], Val Loss: 0.6594
# Step [3/100], Val Loss: 0.7574
# Step [4/100], Val Loss: 0.8542
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 362.7070276469731, MSE: 331922.3566502053, R2: 0.08317338745429459
# Task 2 - MAE: 335.46541181839547, MSE: 275412.20594106434, R2: 0.23926413883356623
# Task 3 - MAE: 191.43019657108042, MSE: 97506.94899574132, R2: 0.7306690436593793
# Subsample rate: 0.001
# Training ANN on task 1 with subsample rate 0.001
# Epoch [1/200], Loss: 1.5363, Val Loss: 0.7600
# Epoch [2/200], Loss: 1.2772, Val Loss: 0.7449
# Epoch [3/200], Loss: 0.7185, Val Loss: 0.7301
# Epoch [4/200], Loss: 0.5747, Val Loss: 0.7180
# Epoch [5/200], Loss: 1.1375, Val Loss: 0.7069
# Epoch [6/200], Loss: 0.7906, Val Loss: 0.6965
# Epoch [7/200], Loss: 0.8362, Val Loss: 0.6890
# Epoch [8/200], Loss: 0.6116, Val Loss: 0.6834
# Epoch [9/200], Loss: 0.8259, Val Loss: 0.6791
# Epoch [10/200], Loss: 0.7863, Val Loss: 0.6747
# Epoch [11/200], Loss: 0.4214, Val Loss: 0.6705
# Epoch [12/200], Loss: 0.7017, Val Loss: 0.6677
# Epoch [13/200], Loss: 0.5574, Val Loss: 0.6655
# Epoch [14/200], Loss: 0.5408, Val Loss: 0.6612
# Epoch [15/200], Loss: 0.5569, Val Loss: 0.6559
# Epoch [16/200], Loss: 0.6704, Val Loss: 0.6498
# Epoch [17/200], Loss: 0.9338, Val Loss: 0.6413
# Epoch [18/200], Loss: 0.9799, Val Loss: 0.6326
# Epoch [19/200], Loss: 0.8353, Val Loss: 0.6229
# Epoch [20/200], Loss: 0.4331, Val Loss: 0.6137
# Epoch [21/200], Loss: 0.2875, Val Loss: 0.6042
# Epoch [22/200], Loss: 0.3764, Val Loss: 0.5962
# Epoch [23/200], Loss: 0.3033, Val Loss: 0.5893
# Epoch [24/200], Loss: 0.5988, Val Loss: 0.5837
# Epoch [25/200], Loss: 0.5034, Val Loss: 0.5812
# Epoch [26/200], Loss: 0.3753, Val Loss: 0.5801
# Epoch [27/200], Loss: 0.6615, Val Loss: 0.5819
# Epoch [28/200], Loss: 0.3798, Val Loss: 0.5851
# Epoch [29/200], Loss: 0.3687, Val Loss: 0.5898
# Epoch [30/200], Loss: 0.4647, Val Loss: 0.5945
# Epoch [31/200], Loss: 0.6051, Val Loss: 0.6007
# Epoch [32/200], Loss: 0.2727, Val Loss: 0.6090
# Epoch [33/200], Loss: 0.2401, Val Loss: 0.6166
# Epoch [34/200], Loss: 0.4816, Val Loss: 0.6248
# Epoch [35/200], Loss: 0.2528, Val Loss: 0.6337
# Epoch [36/200], Loss: 0.3331, Val Loss: 0.6427
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 250.83274841308594, MSE: 105396.7890625, R2: 0.624780025706118
# Task 2 - MAE: 354.5246276855469, MSE: 225238.75, R2: 0.19813422491988641
# Task 3 - MAE: 319.9723815917969, MSE: 178932.9375, R2: 0.36298618719875997
# Training ANN on task 2 with subsample rate 0.001
# Epoch [1/200], Loss: 0.9855, Val Loss: 1.2380
# Epoch [2/200], Loss: 0.5805, Val Loss: 1.2422
# Epoch [3/200], Loss: 0.5620, Val Loss: 1.2397
# Epoch [4/200], Loss: 0.8299, Val Loss: 1.2262
# Epoch [5/200], Loss: 0.3474, Val Loss: 1.2164
# Epoch [6/200], Loss: 0.7465, Val Loss: 1.1971
# Epoch [7/200], Loss: 0.6580, Val Loss: 1.1774
# Epoch [8/200], Loss: 0.6018, Val Loss: 1.1555
# Epoch [9/200], Loss: 0.2929, Val Loss: 1.1440
# Epoch [10/200], Loss: 0.5858, Val Loss: 1.1293
# Epoch [11/200], Loss: 0.3506, Val Loss: 1.1216
# Epoch [12/200], Loss: 0.4557, Val Loss: 1.1169
# Epoch [13/200], Loss: 0.4916, Val Loss: 1.1170
# Epoch [14/200], Loss: 0.3340, Val Loss: 1.1168
# Epoch [15/200], Loss: 0.2371, Val Loss: 1.1200
# Epoch [16/200], Loss: 0.3036, Val Loss: 1.1268
# Epoch [17/200], Loss: 0.1790, Val Loss: 1.1388
# Epoch [18/200], Loss: 0.2032, Val Loss: 1.1521
# Epoch [19/200], Loss: 0.3327, Val Loss: 1.1681
# Epoch [20/200], Loss: 0.3247, Val Loss: 1.1784
# Epoch [21/200], Loss: 0.2788, Val Loss: 1.1828
# Epoch [22/200], Loss: 0.3804, Val Loss: 1.1957
# Epoch [23/200], Loss: 0.2892, Val Loss: 1.2018
# Epoch [24/200], Loss: 0.4097, Val Loss: 1.2072
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 273.8797912597656, MSE: 119711.1328125, R2: 0.5738199574361542
# Task 2 - MAE: 249.5371856689453, MSE: 139262.390625, R2: 0.5042161584377605
# Task 3 - MAE: 317.7089538574219, MSE: 190848.1875, R2: 0.3205670268510078
# Training ANN on task 3 with subsample rate 0.001
# Epoch [1/200], Loss: 0.4576, Val Loss: 0.3395
# Epoch [2/200], Loss: 0.6757, Val Loss: 0.3456
# Epoch [3/200], Loss: 0.7264, Val Loss: 0.3563
# Epoch [4/200], Loss: 0.5029, Val Loss: 0.3645
# Epoch [5/200], Loss: 0.5180, Val Loss: 0.3710
# Epoch [6/200], Loss: 0.4484, Val Loss: 0.3674
# Epoch [7/200], Loss: 0.3930, Val Loss: 0.3727
# Epoch [8/200], Loss: 0.7632, Val Loss: 0.3724
# Epoch [9/200], Loss: 0.5387, Val Loss: 0.3803
# Epoch [10/200], Loss: 0.3115, Val Loss: 0.3929
# Epoch [11/200], Loss: 0.4307, Val Loss: 0.3976
# Early stopping triggered
# Evaluating ANN on all tasks
# Task 1 - MAE: 267.8645324707031, MSE: 121742.21875, R2: 0.5665891491039465
# Task 2 - MAE: 272.47076416015625, MSE: 155754.640625, R2: 0.44550259398025205
# Task 3 - MAE: 272.236572265625, MSE: 139217.25, R2: 0.5043767790366536
# Training KAN on task 1 with subsample rate 0.001
# Step [1/100], Val Loss: 0.6527
# Step [2/100], Val Loss: 0.7202
# Step [3/100], Val Loss: 0.7238
# Step [4/100], Val Loss: 0.7239
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 72.75329208267938, MSE: 42249.54813499815, R2: 0.8495886312058122
# Task 2 - MAE: 406.5648645698284, MSE: 302063.5965991443, R2: -0.07536769108630437
# Task 3 - MAE: 416.9379224275288, MSE: 331127.54896975757, R2: -0.17883740973666296
# Training KAN on task 2 with subsample rate 0.001
# Step [1/100], Val Loss: 1.9111
# Step [2/100], Val Loss: 1.9305
# Step [3/100], Val Loss: 1.9302
# Step [4/100], Val Loss: 1.9302
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 346.2029004019995, MSE: 179474.18995045594, R2: 0.3610592357716982
# Task 2 - MAE: 108.74301816060677, MSE: 112661.97311374103, R2: 0.5989154361380129
# Task 3 - MAE: 462.29668053877975, MSE: 347870.84872596624, R2: -0.23844473681187472
# Training KAN on task 3 with subsample rate 0.001
# Step [1/100], Val Loss: 1.0595
# Step [2/100], Val Loss: 1.1254
# Step [3/100], Val Loss: 1.1255
# Step [4/100], Val Loss: 1.1255
# Early stopping triggered
# Evaluating KAN on all tasks
# Task 1 - MAE: 442.37262220692844, MSE: 290808.0593119346, R2: -0.03529718513737046
# Task 2 - MAE: 341.1316369829008, MSE: 202972.5090039798, R2: 0.27740356395457744
# Task 3 - MAE: 99.77915659051192, MSE: 66558.94020705484, R2: 0.7630454822843264

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from kan import KAN, add_symbolic
from torch.utils.data import TensorDataset, DataLoader

# Load the dataset
data_path = 'WallWindowTypicalDays_Winter Typical.csv'
data = pd.read_csv(data_path)

# Define input and output columns
input_columns = ['Temp', 'Dew', 'Hum', 'Pres', 'Wall Area', 'Window Area', 'Orientation', 'u-Value (Wall)', 'u-Value (Windows)', 'g-Value (Windows)']
output_column = 'Winter Typical:Heat Flow'
num_tasks = 3

# Prepare the data
X = data[input_columns].values
y = data[output_column].values

# Define subsampling rates
subsample_rates = [0.1, 0.05, 0.025, 0.001]

# Define the ANN model
class ANN(nn.Module):
    def __init__(self):
        super(ANN, self).__init__()
        self.layer1 = nn.Linear(X.shape[1], 64)
        self.layer2 = nn.Linear(64, 32)
        self.layer3 = nn.Linear(32, 1)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = self.layer3(x)
        return x

# Train the ANN model with early stopping
def train_ann(model, train_loader, val_loader, criterion, optimizer, epochs=200, patience=10):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        # Validation step
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                outputs = model(inputs)
                val_loss += criterion(outputs, targets).item()
        val_loss /= len(val_loader)

        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss:.4f}')

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered")
            break

    # Load the best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

# Evaluate the ANN model
def evaluate_ann(model, test_loader):
    model.eval()
    all_predictions = []
    all_actuals = []
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            all_predictions.append(outputs.numpy())
            all_actuals.append(targets.numpy())
    predictions = np.concatenate(all_predictions)
    actuals = np.concatenate(all_actuals)
    return predictions, actuals

# Define function to calculate performance metrics
def calculate_metrics(predictions, actuals, y_std, y_mean):
    predictions_denorm = predictions * y_std + y_mean
    actuals_denorm = actuals * y_std + y_mean
    mae = mean_absolute_error(actuals_denorm, predictions_denorm)
    mse = mean_squared_error(actuals_denorm, predictions_denorm)
    r2 = r2_score(actuals_denorm, predictions_denorm)
    return mae, mse, r2

# Train the KAN model using the tutorial's approach with early stopping
def train_kan_with_early_stopping(model, dataset, patience=5, steps=200):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    optimizer = torch.optim.LBFGS(model.parameters(), lr=1)

    def closure():
        optimizer.zero_grad()
        outputs = model(dataset['train_input'])
        loss = nn.MSELoss()(outputs, dataset['train_label'])
        loss.backward()
        return loss

    for step in range(steps):
        optimizer.step(closure)
        
        # Validation step
        with torch.no_grad():
            val_outputs = model(dataset['test_input'])
            val_loss = nn.MSELoss()(val_outputs, dataset['test_label']).item()

        print(f'Step [{step+1}/{steps}], Val Loss: {val_loss:.4f}')

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print("Early stopping triggered")
            break

    # Load the best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)

# Function to train and evaluate models on each subsample rate
def train_and_evaluate_models(subsample_rate, X, y):
    # Subsample the data
    if subsample_rate < 1:
        X_sub, _, y_sub, _ = train_test_split(X, y, test_size=1 - subsample_rate, random_state=42)
    else:
        X_sub, y_sub = X, y

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_sub, y_sub, test_size=0.2, random_state=42)

    # Normalize the data
    scaler_X = StandardScaler()
    scaler_y = StandardScaler()

    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()
    y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1)).flatten()

    # Convert to tensors
    X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
    X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train_scaled, dtype=torch.float32).unsqueeze(1)
    y_test_tensor = torch.tensor(y_test_scaled, dtype=torch.float32).unsqueeze(1)

    # Create data loaders
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Initialize and train the ANN model
    ann_model = ANN()
    criterion = nn.MSELoss()
    optimizer = optim.Adam(ann_model.parameters(), lr=0.001)

    print(f"Training ANN with subsample rate {subsample_rate}")
    train_ann(ann_model, train_loader, test_loader, criterion, optimizer, epochs=200, patience=10)

    print("Evaluating ANN on test set")
    predictions_ann, actuals_ann = evaluate_ann(ann_model, test_loader)
    mae_ann, mse_ann, r2_ann = calculate_metrics(predictions_ann, actuals_ann, y_std=scaler_y.scale_[0], y_mean=scaler_y.mean_[0])

    # Initialize and train the KAN model
    kan_model = KAN(width=[len(input_columns), 20, 1], grid=10, k=10, seed=0)
    dataset = {
        'train_input': X_train_tensor,
        'train_label': y_train_tensor,
        'test_input': X_test_tensor,
        'test_label': y_test_tensor
    }

    print(f"Training KAN with subsample rate {subsample_rate}")
    train_kan_with_early_stopping(kan_model, dataset, patience=3, steps=100)

    print("Evaluating KAN on test set")
    with torch.no_grad():
        predictions_kan_scaled = kan_model(X_test_tensor).numpy()
    mae_kan, mse_kan, r2_kan = calculate_metrics(predictions_kan_scaled, y_test_scaled, y_std=scaler_y.scale_[0], y_mean=scaler_y.mean_[0])

    return r2_ann, r2_kan

# Perform the training and evaluation for each subsample rate
ann_r2_scores = []
kan_r2_scores = []

for subsample_rate in subsample_rates:
    print(f"Subsample rate: {subsample_rate}")
    r2_ann, r2_kan = train_and_evaluate_models(subsample_rate, X, y)
    ann_r2_scores.append(r2_ann)
    kan_r2_scores.append(r2_kan)

# Convert lists to numpy arrays for easier plotting
ann_r2_scores = np.array(ann_r2_scores)
kan_r2_scores = np.array(kan_r2_scores)

# Plot the R² comparison for ANN and KAN with different subsample rates
plt.figure(figsize=(14, 7))
bar_width = 0.35
index = np.arange(len(subsample_rates))

plt.bar(index, ann_r2_scores, bar_width, label='ANN')
plt.bar(index + bar_width, kan_r2_scores, bar_width, label='KAN')

plt.xlabel('Subsample Rate')
plt.ylabel('R² Score')
plt.title('R² Comparison of ANN and KAN with Different Subsample Rates')
plt.xticks(index + bar_width / 2, subsample_rates)
plt.legend()
plt.tight_layout()
plt.savefig('R2_Comparison_Subsample_Rates.png', dpi=300)
plt.show()
# Out:
# Subsample rate: 0.1
# Training ANN with subsample rate 0.1
# Epoch [1/200], Loss: 0.3894, Val Loss: 0.6703
# Epoch [2/200], Loss: 0.4053, Val Loss: 0.6149
# Epoch [3/200], Loss: 0.1895, Val Loss: 0.5562
# Epoch [4/200], Loss: 0.7865, Val Loss: 0.4996
# Epoch [5/200], Loss: 0.4002, Val Loss: 0.4675
# Epoch [6/200], Loss: 0.0669, Val Loss: 0.4352
# Epoch [7/200], Loss: 0.1690, Val Loss: 0.4036
# Epoch [8/200], Loss: 0.0579, Val Loss: 0.4199
# Epoch [9/200], Loss: 0.3636, Val Loss: 0.3911
# Epoch [10/200], Loss: 0.1170, Val Loss: 0.3571
# Epoch [11/200], Loss: 0.2103, Val Loss: 0.3525
# Epoch [12/200], Loss: 0.0804, Val Loss: 0.3273
# Epoch [13/200], Loss: 0.1288, Val Loss: 0.3325
# Epoch [14/200], Loss: 0.2949, Val Loss: 0.3299
# Epoch [15/200], Loss: 0.0801, Val Loss: 0.3030
# Epoch [16/200], Loss: 0.0389, Val Loss: 0.2948
# Epoch [17/200], Loss: 0.1690, Val Loss: 0.2822
# Epoch [18/200], Loss: 0.1287, Val Loss: 0.2795
# Epoch [19/200], Loss: 0.0660, Val Loss: 0.2897
# Epoch [20/200], Loss: 0.1879, Val Loss: 0.2817
# Epoch [21/200], Loss: 0.3254, Val Loss: 0.2675
# Epoch [22/200], Loss: 0.1733, Val Loss: 0.2713
# Epoch [23/200], Loss: 0.1808, Val Loss: 0.2777
# Epoch [24/200], Loss: 0.0694, Val Loss: 0.2550
# Epoch [25/200], Loss: 0.0482, Val Loss: 0.2500
# Epoch [26/200], Loss: 0.1344, Val Loss: 0.2652
# Epoch [27/200], Loss: 0.0405, Val Loss: 0.2448
# Epoch [28/200], Loss: 0.0597, Val Loss: 0.2384
# Epoch [29/200], Loss: 0.5903, Val Loss: 0.2444
# Epoch [30/200], Loss: 0.0678, Val Loss: 0.2398
# Epoch [31/200], Loss: 0.1580, Val Loss: 0.2295
# Epoch [32/200], Loss: 0.1109, Val Loss: 0.2295
# Epoch [33/200], Loss: 0.0936, Val Loss: 0.2298
# Epoch [34/200], Loss: 0.0703, Val Loss: 0.2229
# Epoch [35/200], Loss: 0.1776, Val Loss: 0.2270
# Epoch [36/200], Loss: 0.0977, Val Loss: 0.2323
# Epoch [37/200], Loss: 0.1097, Val Loss: 0.2199
# Epoch [38/200], Loss: 0.0755, Val Loss: 0.2266
# Epoch [39/200], Loss: 0.1179, Val Loss: 0.2074
# Epoch [40/200], Loss: 0.0704, Val Loss: 0.2096
# Epoch [41/200], Loss: 0.0491, Val Loss: 0.2190
# Epoch [42/200], Loss: 0.0489, Val Loss: 0.2033
# Epoch [43/200], Loss: 0.0836, Val Loss: 0.1990
# Epoch [44/200], Loss: 0.0916, Val Loss: 0.1990
# Epoch [45/200], Loss: 0.0306, Val Loss: 0.2100
# Epoch [46/200], Loss: 0.0279, Val Loss: 0.2054
# Epoch [47/200], Loss: 0.0764, Val Loss: 0.2114
# Epoch [48/200], Loss: 0.1141, Val Loss: 0.2022
# Epoch [49/200], Loss: 0.0649, Val Loss: 0.1991
# Epoch [50/200], Loss: 0.1637, Val Loss: 0.2066
# Epoch [51/200], Loss: 0.7293, Val Loss: 0.1979
# Epoch [52/200], Loss: 0.0774, Val Loss: 0.1966
# Epoch [53/200], Loss: 0.1993, Val Loss: 0.1851
# Epoch [54/200], Loss: 0.0840, Val Loss: 0.2019
# Epoch [55/200], Loss: 0.0590, Val Loss: 0.1950
# Epoch [56/200], Loss: 0.3976, Val Loss: 0.1912
# Epoch [57/200], Loss: 0.1660, Val Loss: 0.1897
# Epoch [58/200], Loss: 0.0132, Val Loss: 0.1864
# Epoch [59/200], Loss: 0.0386, Val Loss: 0.1987
# Epoch [60/200], Loss: 0.0431, Val Loss: 0.2002
# Epoch [61/200], Loss: 0.1270, Val Loss: 0.1872
# Epoch [62/200], Loss: 0.1644, Val Loss: 0.1849
# Epoch [63/200], Loss: 0.3031, Val Loss: 0.1824
# Epoch [64/200], Loss: 0.0665, Val Loss: 0.1744
# Epoch [65/200], Loss: 0.1154, Val Loss: 0.1840
# Epoch [66/200], Loss: 0.0376, Val Loss: 0.1908
# Epoch [67/200], Loss: 0.2261, Val Loss: 0.2042
# Epoch [68/200], Loss: 0.0948, Val Loss: 0.1802
# Epoch [69/200], Loss: 1.8945, Val Loss: 0.1911
# Epoch [70/200], Loss: 0.0476, Val Loss: 0.1981
# Epoch [71/200], Loss: 0.0452, Val Loss: 0.1858
# Epoch [72/200], Loss: 0.0147, Val Loss: 0.1879
# Epoch [73/200], Loss: 0.1531, Val Loss: 0.1845
# Epoch [74/200], Loss: 0.0380, Val Loss: 0.1780
# Early stopping triggered
# Evaluating ANN on test set
# Training KAN with subsample rate 0.1
# Step [1/100], Val Loss: 0.6532
# Step [2/100], Val Loss: 0.3420
# Step [3/100], Val Loss: 0.2909
# Step [4/100], Val Loss: 0.2445
# Step [5/100], Val Loss: 0.2038
# Step [6/100], Val Loss: 0.1536
# Step [7/100], Val Loss: 0.1257
# Step [8/100], Val Loss: 0.1098
# Step [9/100], Val Loss: 0.0989
# Step [10/100], Val Loss: 0.0886
# Step [11/100], Val Loss: 0.0831
# Step [12/100], Val Loss: 0.0787
# Step [13/100], Val Loss: 0.0745
# Step [14/100], Val Loss: 0.0709
# Step [15/100], Val Loss: 0.0669
# Step [16/100], Val Loss: 0.0642
# Step [17/100], Val Loss: 0.0636
# Step [18/100], Val Loss: 0.0620
# Step [19/100], Val Loss: 0.0615
# Step [20/100], Val Loss: 0.0592
# Step [21/100], Val Loss: 0.0585
# Step [22/100], Val Loss: 0.0575
# Step [23/100], Val Loss: 0.0566
# Step [24/100], Val Loss: 0.0549
# Step [25/100], Val Loss: 0.0546
# Step [26/100], Val Loss: 0.0530
# Step [27/100], Val Loss: 0.0518
# Step [28/100], Val Loss: 0.0510
# Step [29/100], Val Loss: 0.0498
# Step [30/100], Val Loss: 0.0491
# Step [31/100], Val Loss: 0.0484
# Step [32/100], Val Loss: 0.0482
# Step [33/100], Val Loss: 0.0473
# Step [34/100], Val Loss: 0.0468
# Step [35/100], Val Loss: 0.0465
# Step [36/100], Val Loss: 0.0466
# Step [37/100], Val Loss: 0.0464
# Step [38/100], Val Loss: 0.0459
# Step [39/100], Val Loss: 0.0457
# Step [40/100], Val Loss: 0.0454
# Step [41/100], Val Loss: 0.0452
# Step [42/100], Val Loss: 0.0448
# Step [43/100], Val Loss: 0.0447
# Step [44/100], Val Loss: 0.0449
# Step [45/100], Val Loss: 0.0447
# Step [46/100], Val Loss: 0.0448
# Step [47/100], Val Loss: 0.0448
# Step [48/100], Val Loss: 0.0445
# Step [49/100], Val Loss: 0.0448
# Step [50/100], Val Loss: 0.0450
# Step [51/100], Val Loss: 0.0453
# Early stopping triggered
# Evaluating KAN on test set
# Subsample rate: 0.05
# Training ANN with subsample rate 0.05
# Epoch [1/200], Loss: 0.3453, Val Loss: 0.6399
# Epoch [2/200], Loss: 0.4158, Val Loss: 0.5887
# Epoch [3/200], Loss: 0.4032, Val Loss: 0.5499
# Epoch [4/200], Loss: 0.2529, Val Loss: 0.5209
# Epoch [5/200], Loss: 0.2849, Val Loss: 0.4789
# Epoch [6/200], Loss: 0.2776, Val Loss: 0.4442
# Epoch [7/200], Loss: 0.1318, Val Loss: 0.4223
# Epoch [8/200], Loss: 0.7460, Val Loss: 0.4560
# Epoch [9/200], Loss: 0.1047, Val Loss: 0.3858
# Epoch [10/200], Loss: 0.1169, Val Loss: 0.3832
# Epoch [11/200], Loss: 0.5884, Val Loss: 0.3680
# Epoch [12/200], Loss: 0.2840, Val Loss: 0.3559
# Epoch [13/200], Loss: 0.1205, Val Loss: 0.3501
# Epoch [14/200], Loss: 0.2515, Val Loss: 0.3391
# Epoch [15/200], Loss: 0.4608, Val Loss: 0.3322
# Epoch [16/200], Loss: 0.1401, Val Loss: 0.3343
# Epoch [17/200], Loss: 0.1474, Val Loss: 0.3231
# Epoch [18/200], Loss: 0.1221, Val Loss: 0.3384
# Epoch [19/200], Loss: 4.0340, Val Loss: 0.3251
# Epoch [20/200], Loss: 0.1293, Val Loss: 0.3074
# Epoch [21/200], Loss: 0.2126, Val Loss: 0.3129
# Epoch [22/200], Loss: 0.4132, Val Loss: 0.3019
# Epoch [23/200], Loss: 3.3995, Val Loss: 0.3215
# Epoch [24/200], Loss: 0.2690, Val Loss: 0.2978
# Epoch [25/200], Loss: 0.1555, Val Loss: 0.2910
# Epoch [26/200], Loss: 0.2387, Val Loss: 0.2841
# Epoch [27/200], Loss: 0.0619, Val Loss: 0.2972
# Epoch [28/200], Loss: 0.1630, Val Loss: 0.2849
# Epoch [29/200], Loss: 0.1457, Val Loss: 0.2874
# Epoch [30/200], Loss: 0.1721, Val Loss: 0.2750
# Epoch [31/200], Loss: 0.0773, Val Loss: 0.2774
# Epoch [32/200], Loss: 0.4521, Val Loss: 0.2735
# Epoch [33/200], Loss: 0.1335, Val Loss: 0.2601
# Epoch [34/200], Loss: 0.3086, Val Loss: 0.2685
# Epoch [35/200], Loss: 0.2432, Val Loss: 0.2714
# Epoch [36/200], Loss: 0.0892, Val Loss: 0.2903
# Epoch [37/200], Loss: 0.6486, Val Loss: 0.2833
# Epoch [38/200], Loss: 0.0667, Val Loss: 0.2629
# Epoch [39/200], Loss: 0.0848, Val Loss: 0.2645
# Epoch [40/200], Loss: 0.1349, Val Loss: 0.2603
# Epoch [41/200], Loss: 0.1473, Val Loss: 0.2438
# Epoch [42/200], Loss: 0.3306, Val Loss: 0.2541
# Epoch [43/200], Loss: 0.1383, Val Loss: 0.2395
# Epoch [44/200], Loss: 0.3128, Val Loss: 0.2479
# Epoch [45/200], Loss: 0.1566, Val Loss: 0.2410
# Epoch [46/200], Loss: 0.3372, Val Loss: 0.2610
# Epoch [47/200], Loss: 0.1179, Val Loss: 0.2361
# Epoch [48/200], Loss: 0.1062, Val Loss: 0.2444
# Epoch [49/200], Loss: 0.1508, Val Loss: 0.2476
# Epoch [50/200], Loss: 0.2624, Val Loss: 0.2457
# Epoch [51/200], Loss: 0.1326, Val Loss: 0.2471
# Epoch [52/200], Loss: 0.1481, Val Loss: 0.2356
# Epoch [53/200], Loss: 0.1024, Val Loss: 0.2190
# Epoch [54/200], Loss: 0.2632, Val Loss: 0.2316
# Epoch [55/200], Loss: 0.1771, Val Loss: 0.2196
# Epoch [56/200], Loss: 0.1073, Val Loss: 0.2320
# Epoch [57/200], Loss: 0.1244, Val Loss: 0.2376
# Epoch [58/200], Loss: 0.1663, Val Loss: 0.2288
# Epoch [59/200], Loss: 0.2283, Val Loss: 0.2225
# Epoch [60/200], Loss: 0.0998, Val Loss: 0.2415
# Epoch [61/200], Loss: 0.2276, Val Loss: 0.2422
# Epoch [62/200], Loss: 0.0763, Val Loss: 0.2472
# Epoch [63/200], Loss: 0.1325, Val Loss: 0.2251
# Early stopping triggered
# Evaluating ANN on test set
# Training KAN with subsample rate 0.05
# Step [1/100], Val Loss: 0.5526
# Step [2/100], Val Loss: 0.3353
# Step [3/100], Val Loss: 0.2754
# Step [4/100], Val Loss: 0.2270
# Step [5/100], Val Loss: 0.1991
# Step [6/100], Val Loss: 0.1710
# Step [7/100], Val Loss: 0.1602
# Step [8/100], Val Loss: 0.1506
# Step [9/100], Val Loss: 0.1487
# Step [10/100], Val Loss: 0.1455
# Step [11/100], Val Loss: 0.1404
# Step [12/100], Val Loss: 0.1355
# Step [13/100], Val Loss: 0.1332
# Step [14/100], Val Loss: 0.1354
# Step [15/100], Val Loss: 0.1356
# Step [16/100], Val Loss: 0.1389
# Early stopping triggered
# Evaluating KAN on test set
# Subsample rate: 0.025
# Training ANN with subsample rate 0.025
# Epoch [1/200], Loss: 0.3069, Val Loss: 0.7477
# Epoch [2/200], Loss: 0.5463, Val Loss: 0.7265
# Epoch [3/200], Loss: 0.3556, Val Loss: 0.7171
# Epoch [4/200], Loss: 0.2515, Val Loss: 0.7013
# Epoch [5/200], Loss: 0.1596, Val Loss: 0.6804
# Epoch [6/200], Loss: 0.2286, Val Loss: 0.6622
# Epoch [7/200], Loss: 0.3294, Val Loss: 0.6549
# Epoch [8/200], Loss: 0.8640, Val Loss: 0.6416
# Epoch [9/200], Loss: 0.6585, Val Loss: 0.6562
# Epoch [10/200], Loss: 0.1155, Val Loss: 0.6182
# Epoch [11/200], Loss: 0.0671, Val Loss: 0.6031
# Epoch [12/200], Loss: 0.4004, Val Loss: 0.5988
# Epoch [13/200], Loss: 0.2199, Val Loss: 0.5918
# Epoch [14/200], Loss: 0.0916, Val Loss: 0.5817
# Epoch [15/200], Loss: 0.1640, Val Loss: 0.5749
# Epoch [16/200], Loss: 0.1017, Val Loss: 0.5650
# Epoch [17/200], Loss: 0.2517, Val Loss: 0.5711
# Epoch [18/200], Loss: 0.2682, Val Loss: 0.5453
# Epoch [19/200], Loss: 0.3352, Val Loss: 0.5409
# Epoch [20/200], Loss: 0.4755, Val Loss: 0.5347
# Epoch [21/200], Loss: 0.1367, Val Loss: 0.5359
# Epoch [22/200], Loss: 0.1761, Val Loss: 0.5101
# Epoch [23/200], Loss: 0.2036, Val Loss: 0.4984
# Epoch [24/200], Loss: 0.1607, Val Loss: 0.5016
# Epoch [25/200], Loss: 0.2338, Val Loss: 0.4859
# Epoch [26/200], Loss: 0.6266, Val Loss: 0.5054
# Epoch [27/200], Loss: 0.1393, Val Loss: 0.4805
# Epoch [28/200], Loss: 0.1104, Val Loss: 0.4899
# Epoch [29/200], Loss: 0.1026, Val Loss: 0.4754
# Epoch [30/200], Loss: 0.3069, Val Loss: 0.4599
# Epoch [31/200], Loss: 0.1213, Val Loss: 0.4688
# Epoch [32/200], Loss: 1.5069, Val Loss: 0.4562
# Epoch [33/200], Loss: 0.2535, Val Loss: 0.4413
# Epoch [34/200], Loss: 0.2038, Val Loss: 0.4519
# Epoch [35/200], Loss: 0.9080, Val Loss: 0.4344
# Epoch [36/200], Loss: 0.2391, Val Loss: 0.4616
# Epoch [37/200], Loss: 0.1310, Val Loss: 0.4214
# Epoch [38/200], Loss: 0.4560, Val Loss: 0.4146
# Epoch [39/200], Loss: 0.1456, Val Loss: 0.4355
# Epoch [40/200], Loss: 0.6322, Val Loss: 0.4320
# Epoch [41/200], Loss: 0.4874, Val Loss: 0.4233
# Epoch [42/200], Loss: 6.1492, Val Loss: 0.4078
# Epoch [43/200], Loss: 1.2048, Val Loss: 0.4034
# Epoch [44/200], Loss: 0.2986, Val Loss: 0.4187
# Epoch [45/200], Loss: 0.2092, Val Loss: 0.4354
# Epoch [46/200], Loss: 0.2893, Val Loss: 0.4081
# Epoch [47/200], Loss: 0.0424, Val Loss: 0.4051
# Epoch [48/200], Loss: 0.3106, Val Loss: 0.3933
# Epoch [49/200], Loss: 0.1410, Val Loss: 0.3880
# Epoch [50/200], Loss: 0.2619, Val Loss: 0.3916
# Epoch [51/200], Loss: 0.0476, Val Loss: 0.3830
# Epoch [52/200], Loss: 0.2832, Val Loss: 0.4147
# Epoch [53/200], Loss: 0.1436, Val Loss: 0.3944
# Epoch [54/200], Loss: 0.1140, Val Loss: 0.4067
# Epoch [55/200], Loss: 0.1506, Val Loss: 0.3919
# Epoch [56/200], Loss: 0.0748, Val Loss: 0.3848
# Epoch [57/200], Loss: 0.1845, Val Loss: 0.3955
# Epoch [58/200], Loss: 0.0594, Val Loss: 0.3928
# Epoch [59/200], Loss: 0.0483, Val Loss: 0.4136
# Epoch [60/200], Loss: 0.3216, Val Loss: 0.3980
# Epoch [61/200], Loss: 0.0607, Val Loss: 0.3861
# Early stopping triggered
# Evaluating ANN on test set
# Training KAN with subsample rate 0.025
# Step [1/100], Val Loss: 0.6635
# Step [2/100], Val Loss: 0.4489
# Step [3/100], Val Loss: 0.4909
# Step [4/100], Val Loss: 0.4894
# Step [5/100], Val Loss: 0.4533
# Early stopping triggered
# Evaluating KAN on test set
# Subsample rate: 0.001
# Training ANN with subsample rate 0.001
# Epoch [1/200], Loss: 0.9007, Val Loss: 1.4548
# Epoch [2/200], Loss: 1.5392, Val Loss: 1.3711
# Epoch [3/200], Loss: 0.7596, Val Loss: 1.2979
# Epoch [4/200], Loss: 1.1475, Val Loss: 1.2286
# Epoch [5/200], Loss: 0.7674, Val Loss: 1.1651
# Epoch [6/200], Loss: 0.3429, Val Loss: 1.1025
# Epoch [7/200], Loss: 0.6364, Val Loss: 1.0438
# Epoch [8/200], Loss: 0.6819, Val Loss: 1.0002
# Epoch [9/200], Loss: 1.3637, Val Loss: 0.9587
# Epoch [10/200], Loss: 0.8389, Val Loss: 0.9206
# Epoch [11/200], Loss: 1.0231, Val Loss: 0.8917
# Epoch [12/200], Loss: 0.6880, Val Loss: 0.8733
# Epoch [13/200], Loss: 1.3440, Val Loss: 0.8607
# Epoch [14/200], Loss: 0.2801, Val Loss: 0.8552
# Epoch [15/200], Loss: 0.5980, Val Loss: 0.8481
# Epoch [16/200], Loss: 0.7241, Val Loss: 0.8444
# Epoch [17/200], Loss: 0.2866, Val Loss: 0.8399
# Epoch [18/200], Loss: 1.0613, Val Loss: 0.8364
# Epoch [19/200], Loss: 0.2794, Val Loss: 0.8365
# Epoch [20/200], Loss: 0.9908, Val Loss: 0.8455
# Epoch [21/200], Loss: 0.2984, Val Loss: 0.8405
# Epoch [22/200], Loss: 0.4153, Val Loss: 0.8418
# Epoch [23/200], Loss: 0.2411, Val Loss: 0.8401
# Epoch [24/200], Loss: 0.2153, Val Loss: 0.8424
# Epoch [25/200], Loss: 0.2766, Val Loss: 0.8423
# Epoch [26/200], Loss: 0.3743, Val Loss: 0.8567
# Epoch [27/200], Loss: 0.4436, Val Loss: 0.8669
# Epoch [28/200], Loss: 0.4011, Val Loss: 0.8760
# Early stopping triggered
# Evaluating ANN on test set
# Training KAN with subsample rate 0.001
# Step [1/100], Val Loss: 1.0244
# Step [2/100], Val Loss: 1.1259
# Step [3/100], Val Loss: 1.1252
# Step [4/100], Val Loss: 1.1252
# Early stopping triggered
# Evaluating KAN on test set
